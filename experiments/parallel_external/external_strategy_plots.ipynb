# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# Out:
# Bad key text.latex.preview in file /opt/anaconda3/lib/python3.8/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle, line 123 ('text.latex.preview : False')
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.5.1/matplotlibrc.template
# or from the matplotlib source distribution
#
# Bad key mathtext.fallback_to_cm in file /opt/anaconda3/lib/python3.8/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle, line 155 ('mathtext.fallback_to_cm : True  # When True, use symbols from the Computer Modern')
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.5.1/matplotlibrc.template
# or from the matplotlib source distribution
#
# ...

# %%
sbis_1 = [53, 53, 53]
sbfw_1 = [53, 53, 53]
giga_1 = [53, 53, 53]
svi_1 = [346, 346, 346]
iht_1 = [53, 53, 53]

s1 = np.array([sbis_1, sbfw_1, giga_1, svi_1, iht_1])

sbis_2 = [3 * 10 ** -5, 3 * 10 ** -5, 3 * 10 ** -5]
sbfw_2 = [0.49, 4.95, 19.8]
giga_2 = [1.08, 10.5, 41.86]
svi_2 = [20.22, 197.4, 796.06]
iht_2 = [3.15, 2.91, 2.88]

s2 = [np.array(sbis_2), np.array(sbfw_2), np.array(giga_2), np.array(svi_2), np.array(iht_2)]
s2 = np.vstack(s2)

sbis_3 = [0, 0, 0]
sbfw_3 = [2e-3, 2e-2, 0.1]
giga_3 = [3e-2, 0.31, 1.22]
svi_3 = [0.16, 1.57, 6.28]
iht_3 = [1.36, 1.53, 1.98]

s3 = np.array([sbis_3, sbfw_3, giga_3, svi_3, iht_3])

sbis_4 = [9e-4, 9e-4, 1e-3]
sbfw_4 = [0.98, 10, 40.2]
giga_4 = [0.23, 2.23, 8.87]
svi_4 = [0.2, 1.9, 8.52]
iht_4 = [3.39, 3.07, 2.94]

s4 = np.array([sbis_4, sbfw_4, giga_4, svi_4, iht_4])

# %%
s4
# Out:
# array([[9.00e-04, 9.00e-04, 1.00e-03],
#        [9.80e-01, 1.00e+01, 4.02e+01],
#        [2.30e-01, 2.23e+00, 8.87e+00],
#        [2.00e-01, 1.90e+00, 8.52e+00],
#        [3.39e+00, 3.07e+00, 2.94e+00]])

# %%
alg_names = ['SBIS', 'SBFW', 'GIGA', 'SVI', 'IHT']

# %%
fig, ax = plt.subplots(2, 2, figsize = (20, 10))

labels = ['k = 2000', 'k = 500', 'k = 50']

ax[0, 0].bar(alg_names, s1[:, 2-i], alpha = 0.4, label = "All k")
        
for i in range(3):
    ax[0, 1].bar(alg_names, s2[:, 2-i], alpha = 0.4, label = labels[i])
    
for i in range(3):
    ax[1, 0].bar(alg_names, s3[:, 2-i], alpha = 0.4, label = labels[i])
    
for i in range(3):
    ax[1, 1].bar(alg_names, s4[:, 2-i], alpha = 0.4, label = labels[i])
    
ax[0, 0].set_title('Step 1')
ax[0, 1].set_title('Step 2')
ax[1, 0].set_title('Step 3')
ax[1, 1].set_title('Step 4')

ax[0, 0].set_ylabel("Time (Sec)")
ax[0, 1].set_ylabel("Time (Sec)")
ax[1, 0].set_ylabel("Time (Sec)")
ax[1, 1].set_ylabel("Time (Sec)")

ax[0, 0].legend()
ax[0, 1].legend()
ax[1, 0].legend()
ax[1, 1].legend()

ax[0, 0].grid()
ax[0, 1].grid()
ax[1, 0].grid()
ax[1, 1].grid()

# %%
# 1. SMG

# %%
fkl_s = [1358.7627025962242,
 1633.4327904517986,
 577.716256956607,
 13.509597260453269,
 941.2470496207682,
 11.92199292874578]

fkl_p = [29.749293769600083,
 17.4297895242882,
 40.36183025414981,
 26.203125717510552,
 62.996259107233065,
 315.3704331276808]

bkl_s = [1371.7113822540384,
 1627.3722687141903,
 580.9005926059805,
 13.563782327181999,
 949.631639061337,
 11.902286016465416]

bkl_p = [327.6386183966622,
 85.88848176011572,
 165.3327959179821,
 97.27732104730782,
 163.33443648659735,
 720.5368321361025]

time_s = [779.8719487190247,
 800.5873231887817,
 815.9593460559845,
 851.1231389045715,
 859.1312372684479,
 872.4340128898621]

time_p = [136.34799909591675,
 154.4262571334839,
 220.8432948589325,
 177.96477794647217,
 290.3898820877075,
 425.7371668815613]

# %%
coreset_sizes = np.arange(100, 1200, 200)

# %%
def errorb(B, delta):
    return (1 + B) + B * np.sqrt(2 * np.log(1 / delta))

# %%
fig, ax = plt.subplots(1, 3, figsize = (20, 8))
ax[0].scatter(coreset_sizes, fkl_s, label = 'SBFW (Seq)', s = 100, alpha = 0.7)
ax[0].scatter(coreset_sizes, fkl_p, label = 'GBC(E) (SBFW)', s = 100, alpha = 0.7)

for c in coreset_sizes:
    ax[0].axvline(c, ls = '--', c = 'gray')

ax[0].legend()
ax[0].grid()
ax[0].set_ylabel('FKL')
ax[0].set_xlabel('Coreset Size')
ax[0].set_title('FKL')

ax[1].scatter(coreset_sizes, bkl_s, label = 'SBFW (Seq)', s = 100, alpha = 0.7)
ax[1].scatter(coreset_sizes, bkl_p, label = 'GBC(E)', s = 100, alpha = 0.7)
ax[1].legend()
ax[1].grid()
ax[1].set_ylabel('BKL')
ax[1].set_xlabel('Coreset Size')
ax[1].set_title('BKL')

for c in coreset_sizes:
    ax[1].axvline(c, ls = '--', c = 'gray')

ax[2].plot(coreset_sizes, time_s, label = 'SBFW (Seq)')
ax[2].plot(coreset_sizes, time_p, label = 'GBC(E)')
ax[2].legend()
ax[2].grid()
ax[2].set_ylabel('Time (sec)')
ax[2].set_xlabel('Coreset Size')
ax[2].set_title('Time')
# Out:
# Text(0.5, 1.0, 'Time')

# %%
# 3. BGR

# %%
maes_s = [6.19662314015153, 1347497956500.1152, 6.195934700270165, 6.196623140232768, 5229108350107.463, 6.196623140295206]
maes_p = [2334533407020.46, 54289799125.41233, 2707155061358.002, 3350393518881.3804, 1045530775975.2806, 12682.649908729722] 
time_s = [10.216175079345703, 9.570101976394653, 11.285329818725586, 10.544034004211426, 10.515321016311646, 11.160501956939697] 
time_p = [2.7568118572235107, 3.010902166366577, 3.671027898788452, 3.693352222442627, 4.501672267913818, 8.422565937042236]

# %%
fig, ax = plt.subplots(1, 2, figsize = (20, 8))
ax[0].scatter(coreset_sizes, maes_s, label = 'SBFW (Seq)', s = 100, alpha = 0.7)
ax[0].scatter(coreset_sizes, maes_p, label = 'GBC(E)', s = 100, alpha = 0.7)
ax[0].legend()
ax[0].grid()
ax[0].set_ylabel('MAE')
ax[0].set_xlabel('Coreset Size')
ax[0].set_title('MAE')

ax[1].plot(coreset_sizes, time_s, label = 'SBFW (Seq)')
ax[1].plot(coreset_sizes, time_p, label = 'GBC(E)')
ax[1].legend()
ax[1].grid()
ax[1].set_ylabel('Time (sec)')
ax[1].set_xlabel('Coreset Size')
ax[1].set_title('Time')

for c in coreset_sizes:
    ax[0].axvline(c, ls = '--', c = 'gray')
    ax[1].axvline(c, ls = '--', c = 'gray')

# %%
# 2. SGR

# %%
fkl_s = [3817947.9457916426,
 635688.230445658,
 275824.98663851153,
 5370198.094718323,
 275824.96765141666,
 275824.98554350546]

fkl_p = [190651.30741271665,
 125407.8916387485,
 323100.34765373747,
 203095.06918820116,
 216318.61398006088,
 362531.43233654596]

bkl_s = [63501654.35056317,
 1364203.6218052418,
 5014345.790720085,
 18888276.065460183,
 5014345.790877378,
 5014345.790729156]

bkl_p = [13141749.572469184,
 5017091.829825173,
 9797069.641232023,
 5015164.690825948,
 5014974.7443423765,
 892871.3891779729]

time_s = [123.36078095436096,
 114.1274995803833,
 111.83005213737488,
 116.71299481391907,
 114.38440823554993,
 117.98503398895264]

time_p = [19.24512004852295,
 37.70613193511963,
 46.82135081291199,
 68.98072600364685,
 70.3929750919342,
 112.21016693115234]

# %%
coreset_sizes = np.arange(100, 1200, 200)

fig, ax = plt.subplots(1, 3, figsize = (20, 8))
ax[0].scatter(coreset_sizes, fkl_s, label = 'SBFW (Seq)', s = 100, alpha = 0.7)
ax[0].scatter(coreset_sizes, fkl_p, label = 'GBC(E) (SBFW)', s = 100, alpha = 0.7)

for c in coreset_sizes:
    ax[0].axvline(c, ls = '--', c = 'gray')

ax[0].legend()
ax[0].grid()
ax[0].set_ylabel('FKL')
ax[0].set_xlabel('Coreset Size')
ax[0].set_title('FKL')

ax[1].scatter(coreset_sizes, bkl_s, label = 'SBFW (Seq)', s = 100, alpha = 0.7)
ax[1].scatter(coreset_sizes, bkl_p, label = 'GBC(E)', s = 100, alpha = 0.7)
ax[1].legend()
ax[1].grid()
ax[1].set_ylabel('BKL')
ax[1].set_xlabel('Coreset Size')
ax[1].set_title('BKL')

for c in coreset_sizes:
    ax[1].axvline(c, ls = '--', c = 'gray')

ax[2].plot(coreset_sizes, time_s, label = 'SBFW (Seq)')
ax[2].plot(coreset_sizes, time_p, label = 'GBC(E)')
ax[2].legend()
ax[2].grid()
ax[2].set_ylabel('Time (sec)')
ax[2].set_xlabel('Coreset Size')
ax[2].set_title('Time')
# Out:
# Text(0.5, 1.0, 'Time')

# %%
# 4. Images
tvs_s = [3097.0, 2075.5, 1429.0, 1437.0] 
tvs_p = [2699.0, 938.0, 522.5, 392.0] 
time_s = [77.37794208526611, 78.96379208564758, 83.03110194206238, 80.48514938354492] 
time_p = [101.79196906089783, 113.66844487190247, 124.61924409866333, 141.19095587730408]
coreset_sizes = np.arange(10, 201, 50)

# %%
fig, ax = plt.subplots(1, 2, figsize = (20, 8))
ax[0].scatter(coreset_sizes, tvs_s, label = 'SBFW (Seq)', s = 100, alpha = 0.7)
ax[0].scatter(coreset_sizes, tvs_p, label = 'GBC(E)', s = 100, alpha = 0.7)
ax[0].legend()
ax[0].grid()
ax[0].set_ylabel('TVD')
ax[0].set_xlabel('Coreset Size')
ax[0].set_title('TVD')

ax[1].plot(coreset_sizes, time_s, label = 'SBFW (Seq)')
ax[1].plot(coreset_sizes, time_p, label = 'GBC(E)')
ax[1].legend()
ax[1].grid()
ax[1].set_ylabel('Time (sec)')
ax[1].set_xlabel('Coreset Size')
ax[1].set_title('Time')

for c in coreset_sizes:
    ax[0].axvline(c, ls = '--', c = 'gray')
    ax[1].axvline(c, ls = '--', c = 'gray')

# %%
# SMG

# %%
# GIGA
fkl_s = [15019.312847713634,
 9349.092046072858,
 19695.474094253736,
 4960.775743698882,
 10806.685904243734,
 1800.940762539063]

bkl_s = [6214.332730193884,
 5071.618652170817,
 7439.333104291896,
 2515.4855270214753,
 5741.078494056078,
 892.5161049629744]

fkl_p = [307.07368347311376,
 554.6628449368116,
 1129.8972803850186,
 2378.160846012451,
 4861.735265624688,
 2380.5024465784945]

bkl_p = [2032.1653278099975,
 1796.4380922919297,
 1778.2857905333353,
 5195.908599099552,
 5577.778552544496,
 3048.672726232473]

time_s = [780.6731178760529,
 791.5978820323944,
 762.6630041599274,
 759.4191091060638,
 769.6101410388947,
 791.2607810497284]

time_p = [155.72611904144287,
 179.8381221294403,
 304.62717604637146,
 182.51288676261902,
 287.36264395713806,
 406.80592823028564]

# %%
coreset_sizes = np.arange(100, 1200, 200)

fig, ax = plt.subplots(1, 3, figsize = (20, 8))
ax[0].scatter(coreset_sizes, fkl_s, label = 'GIGA (Seq)', s = 100, alpha = 0.7)
ax[0].scatter(coreset_sizes, fkl_p, label = 'GBC(E) (GIGA)', s = 100, alpha = 0.7)

for c in coreset_sizes:
    ax[0].axvline(c, ls = '--', c = 'gray')

ax[0].legend()
ax[0].grid()
ax[0].set_ylabel('FKL')
ax[0].set_xlabel('Coreset Size')
ax[0].set_title('FKL')

ax[1].scatter(coreset_sizes, bkl_s, label = 'GIGA (Seq)', s = 100, alpha = 0.7)
ax[1].scatter(coreset_sizes, bkl_p, label = 'GBC(E) (GIGA)', s = 100, alpha = 0.7)
ax[1].legend()
ax[1].grid()
ax[1].set_ylabel('BKL')
ax[1].set_xlabel('Coreset Size')
ax[1].set_title('BKL')

for c in coreset_sizes:
    ax[1].axvline(c, ls = '--', c = 'gray')

ax[2].plot(coreset_sizes, time_s, label = 'GIGA (Seq)')
ax[2].plot(coreset_sizes, time_p, label = 'GBC(E) (GIGA)')
ax[2].legend()
ax[2].grid()
ax[2].set_ylabel('Time (sec)')
ax[2].set_xlabel('Coreset Size')
ax[2].set_title('Time')
# Out:
# Text(0.5, 1.0, 'Time')

# %%
fkl_s = [4125.314998119884,
 25140.230339871952,
 12209.968255160638,
 9557.85555723329,
 1791.2624754884632,
 4207.901519554057]

fkl_p = [418.08062177865276,
 1037.8155236953066,
 117.97370369115457,
 1670.2489706257295,
 1946.0261831184055,
 3792.3362587901456]

bkl_s = [1974.9216631738745,
 695.8843346918634,
 546.3602148511176,
 289.69093728356233,
 169.8459860591425,
 169.27880646026742]

bkl_p = [7421.043977696174,
 1648.448800898571,
 510.22234906727806,
 568.6026692433185,
 674.5192525941276,
 2998.2635145102386]

time_s = [801.2833070755005,
 770.597617149353,
 762.344398021698,
 791.2468161582947,
 766.5263428688049,
 767.2705011367798]

time_p = [129.13546180725098,
 159.56878805160522,
 222.35200214385986,
 180.492901802063,
 278.5602231025696,
 421.4392638206482]

# %%
coreset_sizes = np.arange(100, 1200, 200)

fig, ax = plt.subplots(1, 3, figsize = (20, 8))
ax[0].scatter(coreset_sizes, fkl_s, label = 'IHT (Seq)', s = 100, alpha = 0.7)
ax[0].scatter(coreset_sizes, fkl_p, label = 'GBC(E) (IHT)', s = 100, alpha = 0.7)

for c in coreset_sizes:
    ax[0].axvline(c, ls = '--', c = 'gray')

ax[0].legend()
ax[0].grid()
ax[0].set_ylabel('FKL')
ax[0].set_xlabel('Coreset Size')
ax[0].set_title('FKL')

ax[1].scatter(coreset_sizes, bkl_s, label = 'IHT (Seq)', s = 100, alpha = 0.7)
ax[1].scatter(coreset_sizes, bkl_p, label = 'GBC(E) (IHT)', s = 100, alpha = 0.7)
ax[1].legend()
ax[1].grid()
ax[1].set_ylabel('BKL')
ax[1].set_xlabel('Coreset Size')
ax[1].set_title('BKL')

for c in coreset_sizes:
    ax[1].axvline(c, ls = '--', c = 'gray')

ax[2].plot(coreset_sizes, time_s, label = 'IHT (Seq)')
ax[2].plot(coreset_sizes, time_p, label = 'GBC(E) (IHT)')
ax[2].legend()
ax[2].grid()
ax[2].set_ylabel('Time (sec)')
ax[2].set_xlabel('Coreset Size')
ax[2].set_title('Time')
# Out:
# Text(0.5, 1.0, 'Time')
